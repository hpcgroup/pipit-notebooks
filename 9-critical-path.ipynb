# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("/home/rakrish/projects/pipit")

# %%
import pipit as pp
import pandas as pd

# %%
# %%html
# <style>
# @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
# </style>
# Out:
# <style>
# @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
# </style>

# %%
THEME_PAPER = """
    attrs:
        Plot:
            height: 350
            width: 700
            toolbar_location: "above"
            outline_line_width: 0
        Title:
            text_font_size: "0pt"
            text_font: "Gill Sans"
        Axis:
            axis_label_text_font_style: "bold"
            axis_label_text_font_size: "18pt"
            axis_label_text_font: "Gill Sans"
            major_label_text_font_size: "16pt"
            major_label_text_font: "Gill Sans"
            minor_tick_line_color: null
        ColorBar:
            major_label_text_font_size: "16pt"
            major_label_text_font: "Gill Sans"
        Toolbar:
            autohide: true
            logo: null
        HoverTool:
            point_policy: "follow_mouse"
        Legend:
            label_text_font_size: "15pt"
            label_text_font: "Gill Sans"
            spacing: 7
            padding: 0
            border_line_color: null
            glyph_width: 16
            glyph_height: 16
            margin: 5
        Scatter:
            size: 12
        DataRange1d:
            range_padding: 0.05
"""
pp.set_option("theme", THEME_PAPER)
pp.set_option("notebook_url", "http://localhost:8889")
# pp.reset_option("theme")

# %%
trace = pp.Trace.from_otf2("/home/rakrish/Downloads/scorep-life-annotated-4-2it/")

# %%
trace.events
# Out:
#      Timestamp (ns) Event Type          Name Thread Process  \
# 0      0.000000e+00    Instant  ProgramBegin      0       0
# 1      3.970454e+04      Enter          main      0       0
# 2      1.172500e+07    Instant  ProgramBegin      0       2
# 3      1.175498e+07      Enter          main      0       2
# 4      1.194867e+07    Instant  ProgramBegin      0       3
# ..              ...        ...           ...    ...     ...
# 99     2.380384e+08      Leave          main      0       1
# 100    2.500455e+08    Instant    ProgramEnd      0       1
# 101    2.500468e+08    Instant    ProgramEnd      0       2
# 102    2.500637e+08    Instant    ProgramEnd      0       0
# 103    2.500647e+08    Instant    ProgramEnd      0       3
#
#                                             Attributes
# 0    {'attributes': {'Attribute 2': 3658747}, 'prog...
# 1                              {'region': 'Region 42'}
# 2    {'attributes': {'Attribute 2': 3658749}, 'prog...
# ...

# %%
critical_paths = trace.critical_path_analysis()
for df in critical_paths:
    display(df.sort_values(by="_matching_timestamp"))
# Out:
#     Timestamp (ns) Event Type       Name  Thread  Process Attributes  \
# 99    2.380384e+08      Leave       main       0        1       None
# 98    2.380381e+08      Leave   sim_life       0        1       None
# 31    2.380373e+08      Leave  main_loop       0        1       None
# 5     2.379496e+08      Leave   MPI_Recv       0        1       None
# 33    2.379405e+08      Leave   MPI_Send       0        0       None
# 8     2.379796e+08      Leave   MPI_Recv       0        0       None
# 6     2.379718e+08      Leave   MPI_Send       0        1       None
# 42    2.379774e+08      Leave   MPI_Send       0        1       None
# 55    2.380156e+08      Leave   MPI_Send       0        0       None
# 15    2.380255e+08      Leave   MPI_Recv       0        1       None
# 17    2.380284e+08      Leave   MPI_Send       0        1       None
# 79    2.380307e+08      Leave   MPI_Send       0        1       None
# 22    2.380319e+08      Leave   MPI_Recv       0        2       None
# ...

# %%
# make sure we are in timeline-vis branch!

# %%
pp.set_option("notebook_url", "http://localhost:8889")

# %%
trace.plot_timeline(critical_path=True, x_start=2.3785e8, x_end=2.3805e8)
# Out:
# <script id="f1e79737-a4d0-4a6b-a368-049ce7f868ef">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:43759/autoload.js?bokeh-autoload-element=f1e79737-a4d0-4a6b-a368-049ce7f868ef&bokeh-absolute-url=http://localhost:43759&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
t2 = pp.Trace.from_otf2("/home/rakrish/Downloads/ScoreP-Kripke-8")

# %%
t2.plot_comm_matrix()
# Out:
# <script id="d948c7bb-428f-44b1-96df-f42ddb5c9943">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:38461/autoload.js?bokeh-autoload-element=d948c7bb-428f-44b1-96df-f42ddb5c9943&bokeh-absolute-url=http://localhost:38461&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
t2.events["Name"].unique().tolist()
# Out:
# ['ProgramBegin',
#  'MPI_Init',
#  'MeasurementOnOff',
#  'SteadyStateSolver',
#  'time-loop',
#  'SweepSolver',
#  'MPI_Irecv',
#  'MpiIrecvRequest',
#  'MPI_Testany',
#  'MPI_Isend',
#  'MpiIsend',
#  'MpiIrecv',
#  'MPI_Waitall',
#  'MpiIsendComplete',
#  'population',
#  'MPI_Allreduce',
#  'MpiCollectiveBegin',
#  'MpiCollectiveEnd']

# %%
ping_pong = pp.Trace.from_otf2("../pipit/pipit/tests/data/ping-pong-otf2/")

# %%
ping_pong.plot_timeline(
    # instant_events=True,
    # messages="all",
    critical_path=True,
    x_start=1.92e8,
    x_end=2e8
)
# Out:
# <script id="c4cdfb2c-3d66-41ac-aa7e-5e9680ff3d0f">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:43953/autoload.js?bokeh-autoload-element=c4cdfb2c-3d66-41ac-aa7e-5e9680ff3d0f&bokeh-absolute-url=http://localhost:43953&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
