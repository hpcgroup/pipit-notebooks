# %%
# Setup
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append("../pipit")
import pipit as pp

# %%
THEME_PAPER = """
    attrs:
        Plot:
            height: 350
            width: 700
            toolbar_location: "above"
            outline_line_width: 0
        Title:
            text_font_size: "0pt"
            text_font: "Gill Sans"
        Axis:
            axis_label_text_font_style: "bold"
            axis_label_text_font_size: "20pt"
            axis_label_text_font: "Gill Sans"
            major_label_text_font_size: "18pt"
            major_label_text_font: "Gill Sans"
            minor_tick_line_color: null
        ColorBar:
            major_label_text_font_size: "16pt"
            major_label_text_font: "Gill Sans"
        Toolbar:
            autohide: true
            logo: null
        HoverTool:
            point_policy: "follow_mouse"
        Legend:
            label_text_font_size: "17pt"
            label_text_font: "Gill Sans"
            spacing: 7
            padding: 0
            border_line_color: null
            glyph_width: 16
            glyph_height: 16
            margin: 5
        Scatter:
            size: 12
        DataRange1d:
            range_padding: 0.05
"""
pp.set_option("theme", THEME_PAPER)
pp.set_option("notebook_url", "http://localhost:8888")

# %%
laghos = pp.Trace.from_otf2("/home/rakrish/Downloads/laghos-32/")

# %%
laghos.plot_comm_matrix(palette="Sunset11")
# Out:
# <script id="adc0b07a-0d5f-453c-9e8b-f5e038b0a5a0">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:35599/autoload.js?bokeh-autoload-element=adc0b07a-0d5f-453c-9e8b-f5e038b0a5a0&bokeh-absolute-url=http://localhost:35599&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
laghos.plot_comm_matrix(palette="Sunset11", cmap="linear")
# Out:
# <script id="bee34bac-f0e3-49b9-ad15-4b089b1642a2">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:33315/autoload.js?bokeh-autoload-element=bee34bac-f0e3-49b9-ad15-4b089b1642a2&bokeh-absolute-url=http://localhost:33315&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
laghos.plot_message_histogram(bins=50)
# Out:
# <script id="e4b6657e-3291-4825-a53e-cc4eb65c9144">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:34019/autoload.js?bokeh-autoload-element=e4b6657e-3291-4825-a53e-cc4eb65c9144&bokeh-absolute-url=http://localhost:34019&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
laghos.plot_comm_over_time(bins=100)
# Out:
# <script id="fa491d0a-48fe-49d7-a310-965b4fe03843">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:41843/autoload.js?bokeh-autoload-element=fa491d0a-48fe-49d7-a310-965b4fe03843&bokeh-absolute-url=http://localhost:41843&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
