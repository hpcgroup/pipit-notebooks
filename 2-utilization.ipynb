# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../../")

import pipit as pp

# %%
trace = pp.Trace.from_otf2("../../pipit/tests/data/tortuga-otf2-16")
trace.plot_time_profile(num_bins=100, normalized=False)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="10535">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65481/autoload.js?bokeh-autoload-element=10535&bokeh-absolute-url=http://localhost:65481&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace.plot_time_profile(num_bins=100, normalized=False, start_time = 822390000, end_time = 1.75e+9)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="2458">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65380/autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace2 = pp.Trace.from_otf2("../../pipit/tests/data/tortuga-otf2-32")
trace2.plot_time_profile(num_bins=100, normalized=False)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="3215">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65383/autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace2.plot_time_profile(num_bins=100, normalized=False, start_time = 1.19e+9, end_time = 2.21e+9)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="3915">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65387/autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace3 = pp.Trace.from_otf2("../../pipit/tests/data/tortuga-otf2-64")
trace3.plot_time_profile(num_bins=100, normalized=False)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="4672">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65392/autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace3.plot_time_profile(num_bins=100, normalized=False, start_time = 1.59e+9, end_time = 3.25e+9)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="5456">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65396/autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace4 = pp.Trace.from_otf2("../../pipit/tests/data/tortuga-otf2-128")
trace4.plot_time_profile(num_bins=100, normalized=False)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="6213">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65400/autoload.js?bokeh-autoload-element=6213&bokeh-absolute-url=http://localhost:65400&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace4.plot_time_profile(num_bins=100, normalized=False, start_time = 1.63e+9, end_time = 4.07e+9)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="6913">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65404/autoload.js?bokeh-autoload-element=6913&bokeh-absolute-url=http://localhost:65404&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace5 = pp.Trace.from_otf2("../../pipit/tests/data/tortuga-otf2-256")
trace5.plot_time_profile(num_bins=100, normalized=False)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="7670">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65412/autoload.js?bokeh-autoload-element=7670&bokeh-absolute-url=http://localhost:65412&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
trace5.plot_time_profile(num_bins=100, normalized=False, start_time = 1.69e+9, end_time = 4.33e+9)
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="8370">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65414/autoload.js?bokeh-autoload-element=8370&bokeh-absolute-url=http://localhost:65414&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1002', ...)
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=1758&bokeh-absolute-url=http://localhost:65378&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65378', method='GET', uri='/autoload.js?bokeh-autoload-element=1758&bokeh-absolute-url=http://localhost:65378&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, Title(id='1068', ...) is already in a doc
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=1758&bokeh-absolute-url=http://localhost:65378&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65378', method='GET', uri='/autoload.js?bokeh-autoload-element=1758&bokeh-absolute-url=http://localhost:65378&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, Title(id='1068', ...) is already in a doc
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=1758&bokeh-absolute-url=http://localhost:65378&resources=none (::1) 16.11ms
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=1758&bokeh-absolute-url=http://localhost:65378&resources=none (::1) 16.11ms
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65380', method='GET', uri='/autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, Stack(id='1782', ...) is already in a doc
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65380', method='GET', uri='/autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, Stack(id='1782', ...) is already in a doc
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none (::1) 42.49ms
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=2458&bokeh-absolute-url=http://localhost:65380&resources=none (::1) 42.49ms
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65383', method='GET', uri='/autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, BasicTicker(id='2469', ...) is already in a doc
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65383', method='GET', uri='/autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, BasicTicker(id='2469', ...) is already in a doc
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none (::1) 63.94ms
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=3215&bokeh-absolute-url=http://localhost:65383&resources=none (::1) 63.94ms
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65387', method='GET', uri='/autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, Stack(id='3267', ...) is already in a doc
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65387', method='GET', uri='/autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, Stack(id='3267', ...) is already in a doc
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none (::1) 98.29ms
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=3915&bokeh-absolute-url=http://localhost:65387&resources=none (::1) 98.29ms
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65392', method='GET', uri='/autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, ColumnDataSource(id='4036', ...) is already in a doc
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65392', method='GET', uri='/autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, ColumnDataSource(id='4036', ...) is already in a doc
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none (::1) 145.17ms
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=4672&bokeh-absolute-url=http://localhost:65392&resources=none (::1) 145.17ms
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65396', method='GET', uri='/autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, VBar(id='5126', ...) is already in a doc
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:65396', method='GET', uri='/autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/Users/jordanmarry/Desktop/PSSGStuff/pipit-vis/pipit/docs/examples/../../pipit/plotting/_util.py", line 295, in bkapp
#     doc.add_root(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/document.py", line 327, in add_root
#     with self.models.freeze():
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 135, in freeze
#     self._pop_freeze()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 276, in _pop_freeze
#     self.recompute()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/document/models.py", line 224, in recompute
#     ma._attach_document(document)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bokeh/model/model.py", line 580, in _attach_document
#     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
# RuntimeError: Models must be owned by only a single document, VBar(id='5126', ...) is already in a doc
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none (::1) 184.36ms
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=5456&bokeh-absolute-url=http://localhost:65396&resources=none (::1) 184.36ms
